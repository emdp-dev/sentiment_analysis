# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading https://files.pythonhosted.org/packages/6f/4b/bab676953da3103003730b8fcdfadbdd20f333d4add10af949dd5c51e6ed/Sastrawi-1.0.1-py2.py3-none-any.whl (209kB)
#      |████████████████████████████████| 215kB 5.8MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
# DataFrame
import pandas as pd

# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer

# Keras
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM
from keras import utils
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# nltk
import nltk
from nltk.corpus import stopwords
from  nltk.stem import SnowballStemmer

#from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
# Word2vec
import gensim

# Utility
import re
import numpy as np
import os
from collections import Counter
import logging
import time
import pickle
import itertools

# Set log
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# TEXT CLENAING
TEXT_CLEANING_RE = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"

# WORD2VEC 
W2V_SIZE = 300
W2V_WINDOW = 7
W2V_EPOCH = 32
W2V_MIN_COUNT = 10

# KERAS
SEQUENCE_LENGTH = 300
EPOCHS = 8
BATCH_SIZE =1024

# SENTIMENT
POSITIVE = "POSITIVE"
NEGATIVE = "NEGATIVE"
NEUTRAL = "NEUTRAL"
SENTIMENT_THRESHOLDS = (0.4, 0.7)

# EXPORT
KERAS_MODEL = "model.h5"
WORD2VEC_MODEL = "model.w2v"
TOKENIZER_MODEL = "tokenizer.pkl"
ENCODER_MODEL = "encoder.pkl"

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ce87928-8f00-4d41-b7c0-ebfd85e4d3e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ce87928-8f00-4d41-b7c0-ebfd85e4d3e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving out.csv to out.csv

# %%
df = pd.read_csv(r'out.csv',sep=',', engine='python')

# %%
df.head(5)
# Out:
#                                                Tweet  negative
# 0  disaat semua cowok berusaha melacak perhatian ...         1
# 1  RT USER: USER siapa yang telat ngasih tau elu?...         1
# 2  41. Kadang aku berfikir, kenapa aku tetap perc...         0
# 3  USER USER AKU ITU AKU\n\nKU TAU MATAMU SIPIT T...         0
# 4  USER USER Kaum cebong kapir udah keliatan dong...         1

# %%
print("Dataset size:", len(df))
# Out:
# Dataset size: 13169

# %% [markdown]
# mapping data for visualization

# %%
decode_map = {1: "NEGATIVE", 0: "NEUTRAL", -1:"POSITIVE"}
def decode_sentiment(label):
    return decode_map[int(label)]

# %%
df.negative = df.negative.apply(lambda x: decode_sentiment(x))

# %%
target_cnt = Counter(df.negative)

plt.figure(figsize=(16,8))
plt.bar(target_cnt.keys(), target_cnt.values())
plt.title("Dataset labels distribuition")
# Out:
# Text(0.5, 1.0, 'Dataset labels distribuition')

# %% [markdown]
# We want to viszualize the data set to show the distribution of our data. Most of the tweets are neutral. While the datasets are not imbalanced, this distributon may affect our model's accuracy

# %% [markdown]
# Preprocess data

# %%
#from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

#create stemmer
#factory = StemmerFactory()
#stemmers = factory.create_stemmer()

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
important_words = ['janganlah','kasus','kurang','lagian','masalah','masalahnya','manalagi','mempersoalkan','mempertanyakan','mereka','bukan']

# %%
stop_words = set(stopwords.words('indonesian')).difference(important_words)  #for some reason stopwords are not removed i.e ini, dan

# %%
stop_words.remove("tidak")

# %%
stop_words.remove("enggak")

# %%
stop_words.remove("berlebihan")

# %%
stop_words.remove("bermacam")

# %%
stop_words.remove('bermacam-macam')

# %%
print(stop_words)
# Out:
# {'ditandaskan', 'turut', 'segalanya', 'dan', 'kamilah', 'panjang', 'kata', 'berupa', 'dimisalkan', 'dikarenakan', 'sama-sama', 'sempat', 'melihatnya', 'berapakah', 'dijawab', 'dapat', 'naik', 'pihaknya', 'sesegera', 'pertama', 'yang', 'tepat', 'berapapun', 'saja', 'tersebutlah', 'siapakah', 'bermaksud', 'kapan', 'jika', 'adalah', 'padanya', 'kepadanya', 'waktu', 'beginian', 'dikerjakan', 'kami', 'sesudah', 'berlangsung', 'meyakini', 'secara', 'jikalau', 'mengapa', 'sekurangnya', 'ujarnya', 'sambil', 'ditunjukkannya', 'ternyata', 'rasa', 'namun', 'diucapkannya', 'misal', 'menjelaskan', 'toh', 'sebegini', 'menunjuki', 'terjadi', 'diakhiri', 'rasanya', 'dikira', 'nantinya', 'bertutur', 'begitupun', 'mengibaratkan', 'luar', 'rata', 'seterusnya', 'wahai', 'ke', 'sebagainya', 'sekadar', 'makin', 'kapankah', 'menanyakan', 'amatlah', 'bersama', 'berkali-kali', 'cara', 'selamanya', 'sekali-kali', 'lah', 'bagaikan', 'bahwa', 'membuat', 'ia', 'sebaiknya', 'diminta', 'haruslah', 'jadi', 'mempergunakan', 'sendirian', 'diperlukannya', 'mengucapkannya', 'setidaknya', 'ingin', 'dialah', 'datang', 'sewaktu', 'setempat', 'bolehkah', 'khususnya', 'sekalian', 'semakin', 'melainkan', 'tengah', 'segera', 'beberapa', 'bung', 'keluar', 'ibaratnya', 'demikian', 'manakala', 'disebutkan', 'tadinya', 'kebetulan', 'sering', 'lainnya', 'dimaksudnya', 'bilakah', 'tegasnya', 'dimaksud', 'akhiri', 'memberi', 'akankah', 'mulanya', 'pertanyakan', 'kok', 'selanjutnya', 'pun', 'melalui', 'mengibaratkannya', 'kepada', 'bahkan', 'yaitu', 'asal', 'pak', 'dipertanyakan', 'kira', 'cuma', 'empat', 'bukanlah', 'dia', 'semata', 'tiap', 'bagai', 'boleh', 'malahan', 'sekadarnya', 'pada', 'kala', 'wah', 'itu', 'apatah', 'merupakan', 'tentu', 'disinilah', 'lanjutnya', 'masa', 'sekali', 'terhadapnya', 'bila', 'mengingat', 'sementara', 'betulkah', 'agaknya', 'dilakukan', 'sebut', 'betul', 'percuma', 'sepertinya', 'merekalah', 'keterlaluan', 'kelihatannya', 'artinya', 'seolah', 'menanti-nanti', 'teringat', 'begini', 'akhirnya', 'dilihat', 'pihak', 'sebaliknya', 'diperbuat', 'hari', 'tentunya', 'telah', 'inginkan', 'persoalan', 'diberikannya', 'tanyanya', 'sebab', 'ungkapnya', 'sepanjang', 'tadi', 'setinggi', 'dibuat', 'mungkinkah', 'ketika', 'berapa', 'sinilah', 'atau', 'berakhirnya', 'menurut', 'lamanya', 'tampaknya', 'entah', 'lanjut', 'begitulah', 'siapapun', 'diperkirakan', 'terakhir', 'semaunya', 'atas', 'dua', 'padahal', 'tiga', 'memintakan', 'suatu', 'sekiranya', 'ditanya', 'semuanya', 'cukuplah', 'para', 'bertanya-tanya', 'terkira', 'menaiki', 'tempat', 'berjumlah', 'pertama-tama', 'seseorang', 'tinggi', 'tanya', 'tentulah', 'aku', 'katakan', 'jawab', 'dikatakannya', 'sedangkan', 'juga', 'beginikah', 'nyatanya', 'keseluruhan', 'jelaskan', 'bertanya', 'agak', 'cukupkah', 'tentang', 'mampukah', 'memang', 'seperti', 'hal', 'berturut-turut', 'dong', 'kemudian', 'sekecil', 'ingat', 'rupanya', 'diibaratkannya', 'kira-kira', 'ditunjuki', 'akulah', 'depan', 'saya', 'keduanya', 'teringat-ingat', 'dini', 'supaya', 'sesaat', 'terutama', 'lain', 'dituturkannya', 'entahlah', 'dilalui', 'segala', 'paling', 'terjadilah', 'benar', 'selama', 'usah', 'andalah', 'menambahkan', 'berlalu', 'melihat', 'jumlahnya', 'sana', 'terhadap', 'mirip', 'tunjuk', 'sehingga', 'berawal', 'berikut', 'meski', 'hampir', 'dipergunakan', 'setidak-tidaknya', 'berkeinginan', 'mendatangkan', 'terbanyak', 'jadinya', 'sekitarnya', 'sudahkah', 'yakni', 'kalaupun', 'apabila', 'diberikan', 'diinginkan', 'berada', 'seketika', 'terus', 'bapak', 'diibaratkan', 'kemungkinan', 'jauh', 'justru', 'didatangkan', 'enggaknya', 'menghendaki', 'saatnya', 'se', 'sebegitu', 'sebelum', 'untuk', 'sepantasnya', 'dari', 'maupun', 'setiba', 'dipunyai', 'agar', 'caranya', 'selaku', 'tiba', 'jawabnya', 'secukupnya', 'seberapa', 'menyangkut', 'kedua', 'mengenai', 'menyeluruh', 'mengerjakan', 'sesuatu', 'kelihatan', 'masing', 'sejauh', 'disebut', 'berakhirlah', 'harusnya', 'masihkah', 'di', 'semampu', 'ditanyai', 'siap', 'tapi', 'ditegaska ...

# %%
stop_words.remove('jangan')

# %%
print(stop_words)
# Out:
# {'ditandaskan', 'turut', 'segalanya', 'dan', 'kamilah', 'panjang', 'kata', 'berupa', 'dimisalkan', 'dikarenakan', 'sama-sama', 'sempat', 'melihatnya', 'berapakah', 'dijawab', 'dapat', 'naik', 'pihaknya', 'sesegera', 'pertama', 'yang', 'tepat', 'berapapun', 'saja', 'tersebutlah', 'siapakah', 'bermaksud', 'kapan', 'jika', 'adalah', 'padanya', 'kepadanya', 'waktu', 'beginian', 'dikerjakan', 'kami', 'sesudah', 'berlangsung', 'meyakini', 'secara', 'jikalau', 'mengapa', 'sekurangnya', 'ujarnya', 'sambil', 'ditunjukkannya', 'ternyata', 'rasa', 'namun', 'diucapkannya', 'misal', 'menjelaskan', 'toh', 'sebegini', 'menunjuki', 'terjadi', 'diakhiri', 'rasanya', 'dikira', 'nantinya', 'bertutur', 'begitupun', 'mengibaratkan', 'luar', 'rata', 'seterusnya', 'wahai', 'ke', 'sebagainya', 'sekadar', 'makin', 'kapankah', 'menanyakan', 'amatlah', 'bersama', 'berkali-kali', 'cara', 'selamanya', 'sekali-kali', 'lah', 'bagaikan', 'bahwa', 'membuat', 'ia', 'sebaiknya', 'diminta', 'haruslah', 'jadi', 'mempergunakan', 'sendirian', 'diperlukannya', 'mengucapkannya', 'setidaknya', 'ingin', 'dialah', 'datang', 'sewaktu', 'setempat', 'bolehkah', 'khususnya', 'sekalian', 'semakin', 'melainkan', 'tengah', 'segera', 'beberapa', 'bung', 'keluar', 'ibaratnya', 'demikian', 'manakala', 'disebutkan', 'tadinya', 'kebetulan', 'sering', 'lainnya', 'dimaksudnya', 'bilakah', 'tegasnya', 'dimaksud', 'akhiri', 'memberi', 'akankah', 'mulanya', 'pertanyakan', 'kok', 'selanjutnya', 'pun', 'melalui', 'mengibaratkannya', 'kepada', 'bahkan', 'yaitu', 'asal', 'pak', 'dipertanyakan', 'kira', 'cuma', 'empat', 'bukanlah', 'dia', 'semata', 'tiap', 'bagai', 'boleh', 'malahan', 'sekadarnya', 'pada', 'kala', 'wah', 'itu', 'apatah', 'merupakan', 'tentu', 'disinilah', 'lanjutnya', 'masa', 'sekali', 'terhadapnya', 'bila', 'mengingat', 'sementara', 'betulkah', 'agaknya', 'dilakukan', 'sebut', 'betul', 'percuma', 'sepertinya', 'merekalah', 'keterlaluan', 'kelihatannya', 'artinya', 'seolah', 'menanti-nanti', 'teringat', 'begini', 'akhirnya', 'dilihat', 'pihak', 'sebaliknya', 'diperbuat', 'hari', 'tentunya', 'telah', 'inginkan', 'persoalan', 'diberikannya', 'tanyanya', 'sebab', 'ungkapnya', 'sepanjang', 'tadi', 'setinggi', 'dibuat', 'mungkinkah', 'ketika', 'berapa', 'sinilah', 'atau', 'berakhirnya', 'menurut', 'lamanya', 'tampaknya', 'entah', 'lanjut', 'begitulah', 'siapapun', 'diperkirakan', 'terakhir', 'semaunya', 'atas', 'dua', 'padahal', 'tiga', 'memintakan', 'suatu', 'sekiranya', 'ditanya', 'semuanya', 'cukuplah', 'para', 'bertanya-tanya', 'terkira', 'menaiki', 'tempat', 'berjumlah', 'pertama-tama', 'seseorang', 'tinggi', 'tanya', 'tentulah', 'aku', 'katakan', 'jawab', 'dikatakannya', 'sedangkan', 'juga', 'beginikah', 'nyatanya', 'keseluruhan', 'jelaskan', 'bertanya', 'agak', 'cukupkah', 'tentang', 'mampukah', 'memang', 'seperti', 'hal', 'berturut-turut', 'dong', 'kemudian', 'sekecil', 'ingat', 'rupanya', 'diibaratkannya', 'kira-kira', 'ditunjuki', 'akulah', 'depan', 'saya', 'keduanya', 'teringat-ingat', 'dini', 'supaya', 'sesaat', 'terutama', 'lain', 'dituturkannya', 'entahlah', 'dilalui', 'segala', 'paling', 'terjadilah', 'benar', 'selama', 'usah', 'andalah', 'menambahkan', 'berlalu', 'melihat', 'jumlahnya', 'sana', 'terhadap', 'mirip', 'tunjuk', 'sehingga', 'berawal', 'berikut', 'meski', 'hampir', 'dipergunakan', 'setidak-tidaknya', 'berkeinginan', 'mendatangkan', 'terbanyak', 'jadinya', 'sekitarnya', 'sudahkah', 'yakni', 'kalaupun', 'apabila', 'diberikan', 'diinginkan', 'berada', 'seketika', 'terus', 'bapak', 'diibaratkan', 'kemungkinan', 'jauh', 'justru', 'didatangkan', 'enggaknya', 'menghendaki', 'saatnya', 'se', 'sebegitu', 'sebelum', 'untuk', 'sepantasnya', 'dari', 'maupun', 'setiba', 'dipunyai', 'agar', 'caranya', 'selaku', 'tiba', 'jawabnya', 'secukupnya', 'seberapa', 'menyangkut', 'kedua', 'mengenai', 'menyeluruh', 'mengerjakan', 'sesuatu', 'kelihatan', 'masing', 'sejauh', 'disebut', 'berakhirlah', 'harusnya', 'masihkah', 'di', 'semampu', 'ditanyai', 'siap', 'tapi', 'ditegaska ...

# %%
def preprocess(text, stem=False):
    # Remove link,user and special characters
    text = re.sub(TEXT_CLEANING_RE, ' ', str(text).lower()).strip()
    tokens = []
    for token in text.split():
        if token not in stop_words:
            if stem:
                tokens.append(stemmers.stem(token))
            else:
                tokens.append(token)
    return " ".join(tokens)

# %%
df.Tweet = df.Tweet.apply(lambda x: preprocess(x))

# %%
df.head()
# Out:
#                                                Tweet  negative
# 0  disaat cowok berusaha melacak perhatian gue lo...  NEGATIVE
# 1  rt user user telat ngasih tau elu edan sarap g...  NEGATIVE
# 2  41 kadang berfikir percaya tuhan jatuh berkali...   NEUTRAL
# 3            user user n nku tau matamu sipit diliat   NEUTRAL
# 4  user user kaum cebong kapir udah keliatan dong...  NEGATIVE

# %% [markdown]
# As we can see, stopwords, links, special symbols have been removed. This helps our process to tokenize

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
print("TRAIN size:", len(df_train))
print("TEST size:", len(df_test))
# Out:
# TRAIN size: 10535
# TEST size: 2634

# %% [markdown]
# # WORD2VEC

# %%
documents = [_text.split() for _text in df_train.Tweet]

# %%
w2v_model = gensim.models.word2vec.Word2Vec(size=W2V_SIZE, 
                                            window=W2V_WINDOW, 
                                            min_count=W2V_MIN_COUNT, 
                                            workers=8)
#id_model = gensim.models.Word2Vec.load(path)

# %%
w2v_model.build_vocab(documents)
# Out:
# 2021-01-20 06:04:33,680 : INFO : collecting all words and their counts
# 2021-01-20 06:04:33,685 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-01-20 06:04:33,719 : INFO : PROGRESS: at sentence #10000, processed 141484 words, keeping 23822 word types
# 2021-01-20 06:04:33,723 : INFO : collected 24554 word types from a corpus of 148973 raw words and 10535 sentences
# 2021-01-20 06:04:33,723 : INFO : Loading a fresh vocabulary
# 2021-01-20 06:04:33,736 : INFO : effective_min_count=10 retains 2088 unique words (8% of original 24554, drops 22466)
# 2021-01-20 06:04:33,737 : INFO : effective_min_count=10 leaves 106131 word corpus (71% of original 148973, drops 42842)
# 2021-01-20 06:04:33,745 : INFO : deleting the raw counts dictionary of 24554 items
# 2021-01-20 06:04:33,746 : INFO : sample=0.001 downsamples 41 most-common words
# 2021-01-20 06:04:33,747 : INFO : downsampling leaves estimated 83301 word corpus (78.5% of prior 106131)
# 2021-01-20 06:04:33,754 : INFO : estimated required memory for 2088 words and 300 dimensions: 6055200 bytes
# 2021-01-20 06:04:33,755 : INFO : resetting layer weights

# %%
# words = id_model.wv.vocab.keys()
# vocab_size = len(words)
# print("Vocab size", vocab_size)

# %%
words = w2v_model.wv.vocab.keys()
vocab_size = len(words)
print("Vocab size", vocab_size)
# Out:
# Vocab size 2088

# %%
w2v_model.train(documents, total_examples=len(documents), epochs=W2V_EPOCH)
# Out:
# 2021-01-20 06:04:34,165 : INFO : training model with 8 workers on 2088 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=7
# 2021-01-20 06:04:34,308 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:34,309 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:34,339 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:34,342 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:34,353 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:34,357 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:34,359 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:34,367 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:34,368 : INFO : EPOCH - 1 : training on 148973 raw words (83186 effective words) took 0.2s, 457122 effective words/s
# 2021-01-20 06:04:34,481 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:34,494 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:34,542 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:34,549 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:34,556 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:34,557 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:34,563 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:34,564 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:34,565 : INFO : EPOCH - 2 : training on 148973 raw words (83315 effective words) took 0.2s, 448195 effective words/s
# 2021-01-20 06:04:34,692 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:34,711 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:34,730 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:34,739 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:34,740 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:34,741 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:34,742 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:34,752 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:34,752 : INFO : EPOCH - 3 : training on 148973 raw words (83355 effective words) took 0.2s, 471817 effective words/s
# 2021-01-20 06:04:34,886 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:34,895 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:34,899 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:34,902 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:34,912 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:34,924 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:34,931 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:34,935 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:34,935 : INFO : EPOCH - 4 : training on 148973 raw words (83403 effective words) took 0.2s, 488548 effective words/s
# 2021-01-20 06:04:35,065 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:35,081 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:35,083 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:35,085 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:35,116 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:35,120 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:35,122 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:35,124 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:35,125 : INFO : EPOCH - 5 : training on 148973 raw words (83327 effective words) took 0.2s, 464080 effective words/s
# 2021-01-20 06:04:35,240 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:35,285 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:35,289 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:35,301 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:35,302 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:35,314 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:35,318 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:35,325 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:35,326 : INFO : EPOCH - 6 : training on 148973 raw words (83310 effective words) took 0.2s, 440427 effective words/s
# 2021-01-20 06:04:35,441 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:35,491 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:35,501 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:35,504 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:35,509 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:35,515 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:35,521 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:35,524 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:35,525 : INFO : EPOCH - 7 : training on 148973 raw words (83284 effective words) took 0.2s, 443098 effective words/s
# 2021-01-20 06:04:35,650 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:35,672 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:35,692 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:35,700 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:35,708 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:35,709 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:35,712 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:35,714 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:35,715 : INFO : EPOCH - 8 : training on 148973 raw words (83318 effective words) took 0.2s, 469205 effective words/s
# 2021-01-20 06:04:35,859 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:35,866 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:35,871 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:35,873 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:35,874 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:35,894 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:35,903 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:35,904 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:35,906 : INFO : EPOCH - 9 : training on 148973 raw words (83380 effective words) took 0.2s, 470304 effective words/s
# 2021-01-20 06:04:36,033 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:36,045 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:36,065 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:36,067 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:36,069 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:36,077 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:36,091 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:36,096 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:36,096 : INFO : EPOCH - 10 : training on 148973 raw words (83296 effective words) took 0.2s, 462784 effective words/s
# 2021-01-20 06:04:36,224 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:36,264 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:36,265 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:36,276 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:36,280 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:36,287 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:36,289 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:36,294 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:36,295 : INFO : EPOCH - 11 : training on 148973 raw words (83445 effective words) took 0.2s, 444624 effective words/s
# 2021-01-20 06:04:36,423 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:36,435 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:36,436 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:36,445 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:36,473 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:36,474 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:36,475 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:36,477 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:36,478 : INFO : EPOCH - 12 : training on 148973 raw words (83379 effective words) took 0.2s, 481619 effective words/s
# 2021-01-20 06:04:36,586 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:36,612 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:36,626 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:36,650 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:36,659 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:36,661 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:36,662 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:36,667 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:36,667 : INFO : EPOCH - 13 : training on 148973 raw words (83213 effective words) took 0.2s, 470582 effective words/s
# 2021-01-20 06:04:36,801 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:36,808 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:36,809 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:36,810 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:36,827 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:36,829 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:36,842 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:36,849 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:36,850 : INFO : EPOCH - 14 : training on 148973 raw words (83281 effective words) took 0.2s, 483724 effective words/s
# 2021-01-20 06:04:36,971 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:37,004 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:37,026 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:37,028 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:37,039 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:37,040 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:37,041 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:37,048 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:37,048 : INFO : EPOCH - 15 : training on 148973 raw words (83357 effective words) took 0.2s, 444265 effective words/s
# 2021-01-20 06:04:37,188 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:37,191 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:37,195 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:37,197 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:37,213 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:37,222 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:37,229 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:37,230 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:37,231 : INFO : EPOCH - 16 : training on 148973 raw words (83251 effective words) took 0.2s, 481749 effective words/s
# 2021-01-20 06:04:37,374 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:37,377 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:37,388 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:37,396 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:37,402 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:37,403 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:37,421 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:37,423 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:37,424 : INFO : EPOCH - 17 : training on 148973 raw words (83369 effective words) took 0.2s, 457177 effective words/s
# 2021-01-20 06:04:37,550 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:37,551 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:37,565 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:37,568 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:37,597 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:37,599 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:37,599 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:37,601 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:37,603 : INFO : EPOCH - 18 : training on 148973 raw words (83325 effective words) took 0.2s, 493691 effective words/s
# 2021-01-20 06:04:37,718 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:37,753 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:37,765 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:37,777 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:37,783 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:37,793 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:37,803 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:37,805 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:37,806 : INFO : EPOCH - 19 : training on 148973 raw words (83328 effective words) took 0.2s, 438060 effective words/s
# 2021-01-20 06:04:37,942 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:37,943 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:37,954 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:37,978 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:37,989 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:37,991 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:38,002 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:38,003 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:38,004 : INFO : EPOCH - 20 : training on 148973 raw words (83531 effective words) took 0.2s, 450679 effective words/s
# 2021-01-20 06:04:38,156 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:38,164 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:38,166 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:38,167 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:38,176 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:38,186 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:38,190 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:38,193 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:38,195 : INFO : EPOCH - 21 : training on 148973 raw words (83347 effective words) took 0.2s, 465732 effective words/s
# 2021-01-20 06:04:38,309 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:38,320 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:38,365 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:38,376 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:38,377 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:38,379 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:38,380 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:38,385 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:38,386 : INFO : EPOCH - 22 : training on 148973 raw words (83150 effective words) took 0.2s, 457688 effective words/s
# 2021-01-20 06:04:38,507 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:38,521 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:38,534 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:38,554 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:38,557 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:38,565 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:38,567 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:38,569 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:38,570 : INFO : EPOCH - 23 : training on 148973 raw words (83301 effective words) took 0.2s, 478609 effective words/s
# 2021-01-20 06:04:38,677 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:38,713 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:38,732 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:38,741 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:38,754 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:38,758 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:38,761 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:38,762 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:38,762 : INFO : EPOCH - 24 : training on 148973 raw words (83372 effective words) took 0.2s, 462305 effective words/s
# 2021-01-20 06:04:38,881 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:38,920 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:38,931 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:38,936 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:38,956 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:38,958 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:38,958 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:38,959 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:38,960 : INFO : EPOCH - 25 : training on 148973 raw words (83340 effective words) took 0.2s, 452417 effective words/s
# 2021-01-20 06:04:39,087 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:39,121 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:39,134 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:39,135 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:39,136 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:39,147 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:39,151 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:39,153 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:39,154 : INFO : EPOCH - 26 : training on 148973 raw words (83257 effective words) took 0.2s, 466400 effective words/s
# 2021-01-20 06:04:39,269 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:39,272 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:39,312 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:39,330 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:39,333 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:39,341 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:39,347 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:39,349 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:39,350 : INFO : EPOCH - 27 : training on 148973 raw words (83152 effective words) took 0.2s, 450565 effective words/s
# 2021-01-20 06:04:39,461 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:39,468 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:39,517 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:39,522 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:39,525 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:39,526 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:39,531 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:39,532 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:39,533 : INFO : EPOCH - 28 : training on 148973 raw words (83336 effective words) took 0.2s, 482917 effective words/s
# 2021-01-20 06:04:39,645 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:39,648 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:39,674 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:39,693 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:39,700 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:39,708 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:39,714 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:39,718 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:39,719 : INFO : EPOCH - 29 : training on 148973 raw words (83278 effective words) took 0.2s, 479035 effective words/s
# 2021-01-20 06:04:39,862 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:39,876 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:39,877 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:39,879 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:39,886 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:39,888 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:39,899 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:39,905 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:39,905 : INFO : EPOCH - 30 : training on 148973 raw words (83246 effective words) took 0.2s, 476299 effective words/s
# 2021-01-20 06:04:40,055 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:40,060 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:40,065 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:40,066 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:40,087 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:40,089 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:40,100 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:40,103 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:40,104 : INFO : EPOCH - 31 : training on 148973 raw words (83277 effective words) took 0.2s, 446942 effective words/s
# 2021-01-20 06:04:40,233 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2021-01-20 06:04:40,254 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2021-01-20 06:04:40,255 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2021-01-20 06:04:40,275 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2021-01-20 06:04:40,287 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2021-01-20 06:04:40,293 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-01-20 06:04:40,294 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-01-20 06:04:40,295 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-01-20 06:04:40,296 : INFO : EPOCH - 32 : training on 148973 raw words (83277 effective words) took 0.2s, 466637 effective words/s
# 2021-01-20 06:04:40,298 : INFO : training on a 4767136 raw words (2665986 effective words) took 6.1s, 434769 effective words/s
# (2665986, 4767136)

# %%
#id_model.train(documents, total_examples=len(documents), epochs=W2V_EPOCH)

# %%
w2v_model.wv.most_similar("polisi")
#wv.most_similar()
# Out:
# 2021-01-20 06:04:40,331 : INFO : precomputing L2-norms of word weight vectors
# [('hukum', 0.6682774424552917),
#  ('kasus', 0.6484764814376831),
#  ('tangkap', 0.645500659942627),
#  ('kapolri', 0.6429009437561035),
#  ('rizieq', 0.61041659116745),
#  ('pilih', 0.5987728834152222),
#  ('dugaan', 0.5914477705955505),
#  ('hubungannya', 0.5678354501724243),
#  ('status', 0.5656869411468506),
#  ('ditangkap', 0.565371572971344)]

# %%
w2v_model.save('word2vec.model')
# Out:
# 2021-01-20 06:04:40,350 : INFO : saving Word2Vec object under word2vec.model, separately None
# 2021-01-20 06:04:40,352 : INFO : not storing attribute vectors_norm
# 2021-01-20 06:04:40,356 : INFO : not storing attribute cum_table
# 2021-01-20 06:04:40,437 : INFO : saved word2vec.model

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df_train.Tweet)

vocab_size = len(tokenizer.word_index) + 1
print("Total words", vocab_size)
# Out:
# Total words 24555

# %%
x_train = pad_sequences(tokenizer.texts_to_sequences(df_train.Tweet), maxlen=SEQUENCE_LENGTH)
x_test = pad_sequences(tokenizer.texts_to_sequences(df_test.Tweet), maxlen=SEQUENCE_LENGTH)

# %%
#label encode
labels = df_train.negative.unique().tolist()

# %%
encoder = LabelEncoder()
encoder.fit(df_train.negative.tolist())

y_train = encoder.transform(df_train.negative.tolist())
y_test = encoder.transform(df_test.negative.tolist())

y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

print("y_train",y_train.shape)
print("y_test",y_test.shape)
# Out:
# y_train (10535, 1)
# y_test (2634, 1)

# %%
#embedding is to help us cluster the words together 
embedding_matrix = np.zeros((vocab_size, W2V_SIZE))
for word, i in tokenizer.word_index.items():
  if word in w2v_model.wv:
    embedding_matrix[i] = w2v_model.wv[word]
print(embedding_matrix.shape)
# Out:
# (24555, 300)

# %%
embedding_layer = Embedding(vocab_size, W2V_SIZE, weights=[embedding_matrix], input_length=SEQUENCE_LENGTH, trainable=False)

# %%
from tensorflow.keras.layers import Input, Dense, Embedding, LSTM, GlobalMaxPooling1D
from tensorflow.keras.models import Model

model = Sequential()
model.add(embedding_layer)
model.add(Dropout(0.5))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# 2021-01-20 06:04:46,500 : WARNING : Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 300, 300)          7366500
# _________________________________________________________________
# dropout (Dropout)            (None, 300, 300)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               160400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 7,527,001
# Trainable params: 160,501
# Non-trainable params: 7,366,500
# _________________________________________________________________

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# %%
callbacks = [ ReduceLROnPlateau(monitor='val_loss', patience=5, cooldown=0),
              EarlyStopping(monitor='val_acc', min_delta=1e-4, patience=5)]

# %%
history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=EPOCHS,
                    validation_split=0.1,
                    verbose=1,
                    callbacks=callbacks)
# Out:
# Epoch 1/8
# 75/75 [==============================] - 79s 1s/step - loss: 0.5253 - accuracy: 0.7430 - val_loss: 0.3863 - val_accuracy: 0.8321
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2021-01-20 06:06:05,576 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 2/8
# 75/75 [==============================] - 75s 993ms/step - loss: 0.4191 - accuracy: 0.8122 - val_loss: 0.3643 - val_accuracy: 0.8406
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2021-01-20 06:07:20,105 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 3/8
# 75/75 [==============================] - 74s 987ms/step - loss: 0.3990 - accuracy: 0.8177 - val_loss: 0.3472 - val_accuracy: 0.8435
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2021-01-20 06:08:34,217 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 4/8
# 75/75 [==============================] - 74s 982ms/step - loss: 0.3669 - accuracy: 0.8383 - val_loss: 0.3419 - val_accuracy: 0.8510
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2021-01-20 06:09:47,916 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 5/8
# 75/75 [==============================] - 73s 977ms/step - loss: 0.3590 - accuracy: 0.8399 - val_loss: 0.3267 - val_accuracy: 0.8539
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2021-01-20 06:11:01,248 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 6/8
# 75/75 [==============================] - 74s 982ms/step - loss: 0.3429 - accuracy: 0.8464 - val_loss: 0.3260 - val_accuracy: 0.8567
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2021-01-20 06:12:14,933 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 7/8
# 75/75 [==============================] - 74s 983ms/step - loss: 0.3312 - accuracy: 0.8565 - val_loss: 0.3132 - val_accuracy: 0.8539
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2021-01-20 06:13:28,649 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 8/8
# 75/75 [==============================] - 73s 979ms/step - loss: 0.3128 - accuracy: 0.8656 - val_loss: 0.3055 - val_accuracy: 0.8738
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 2021-01-20 06:14:42,086 : WARNING : Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr

# %%
#evaluate model 
score = model.evaluate(x_test, y_test, batch_size=300)
print()
print("ACCURACY:",score[1])
print("LOSS:",score[0])
# Out:
# 9/9 [==============================] - 1s 101ms/step - loss: 0.3178 - accuracy: 0.8618
#
# ACCURACY: 0.861807107925415
# LOSS: 0.31779929995536804

# %%
#ROC vizialization
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
def decode_sentiment(score, include_neutral=True):
    if include_neutral:        
        label = NEUTRAL
        if score <= SENTIMENT_THRESHOLDS[0]:
            label = NEGATIVE
        elif score >= SENTIMENT_THRESHOLDS[1]:
            label = NEUTRAL

        return label
    else:
        return NEGATIVE if score < 0.5 else NEUTRAL

# %%
def predict(text, include_neutral=True):
    start_at = time.time()
    # Tokenize text
    x_test = pad_sequences(tokenizer.texts_to_sequences([text]), maxlen=SEQUENCE_LENGTH)
    # Predict
    score = model.predict([x_test])[0]
    # Decode sentiment
    label = decode_sentiment(score, include_neutral=include_neutral)

    return {"label": label, "score": float(score),
       "elapsed_time": time.time()-start_at}

# %%
predict("  Sebanyak 2.630 tenaga kesehatan (nakes) di RSD Wisma Atlet Kemayoran, Jakarta Pusat, bakal divaksinasi COVID-19 secara bertahap. Vaksinasi terhadap para tenaga kesehatan ini diprioritaskan karena mereka bersinggungan langsung dengan pasien.Sekitar 2.630 orang ini yang kita prioritaskan, karena mereka langsung bersinggungan dengan para pasien, ujar Pangdam Jaya Mayjen TNI Dudung Abdurachman, kepada wartawan, Rabu (20/1/2021).Pelaksanaan vaksinasi terhadap nakes ini dimulai dari pukul 09.00 WIB sampai 13.00 WIB. Sampai pukul 09.40 WIB, vaksinasi sudah berjalan 25%.Jumlah tenaga kesehatan yang divaksinasi di Wisma Atlet sebanyak 180 dalam setiap hari. Hari ini merupakan hari kedua proses vaksinasi di Wisma Atlet.Jadi saat ini sudah mencapai kurang-lebih sekitar 25% dan ini berlanjut dari jam 09.00 WIB sampai jam 13.00 WIB, kata Dudung.Dudung turut memantau pelaksanaan vaksinasi yang dilaksanakan di Tower 3, Lt 2 Wisma Atlet. Dudung juga terlihat bertanya kepada salah satu nakes yang sudah disuntik vaksin.Kemudian tadi saya tanya langsung kepada nakes yang tadi sudah disuntik, tidak ada dampak apa pun, sehat-sehat saja dan seperti biasa, kata Dudung.Dudung mengatakan pelaksanaan vaksinasi terhadap nakes ini berjalan dengan lancar. Tempat menyimpan vaksin pun sudah sesuai dengan standar di masing-masing puskesmas.Tadi saya lihat secara langsung bahwa, pelaksanaan berjalan lancar. Karena tenaga kerja memang profesional, kemudian vaksin juga disimpan di tempat yang sudah sesuai dengan standar di masing-masing puskesmas, ujar Dudung.Proses vaksinasi itu selanjutnya akan diberikan kepada tenaga profesional lainnya. Tenaga profesional yang akan divaksinasi setelah nakes di antaranya anggota TNI, kepolisian, guru, dan profesional lainnya.Pelaksanaan ini hanya ditujukan kepada tenaga kesehatan terlebih dahulu. Selanjutnya bertahap nanti akan diberikan kepada tenaga profesional dan pelayanan publik, ujar Dudung.Ya seperti anggota TNI, kepolisian kemudian guru dan profesional lainnya, sambung Dudung.")
# Out:
# {'elapsed_time': 0.10926079750061035,
#  'label': 'NEUTRAL',
#  'score': 0.9932811260223389}

# %%
predict("Jakarta - Aksi Raffi Ahmad yang datang ke pesta ulang tahun Ricardo Gelael usai divaksinasi Corona berbuntut panjang. Ada juga pihak yang menggugat Raffi Ahmad secara perdata karena dianggap melanggar protokol kesehatan.Raffi Ahmad digugat perdata oleh advokat David Tobing di Pengadilan Negeri Depok. David Tobing menilai apa yang dilakukan oleh Raffi Ahmad datang ke pesta usai disuntik vaksin Corona melanggar protokol kesehatan.27 Januari 2021 sidang perdana Raffi Ahmad terkait gugatan tersebut akan digelar. Pihak pengadilan pun sudah mengirimkan surat panggilan kepada Raffi Ahmad.Jadi setelah majelis hakim mengeluarkan penetapan hari sidang, kemudian memerintahkan jurusita pengadilan untuk melakukan panggilan kepada para pihak, jelas Humas Pengadilan Negeri Depok, Nanang Herjunanto melalui sambungan telepon.Panggilan itu sah dan patutnya tiga hari sebelum sidang itu dilaksanakan, imbuhnya.Akan tetapi, Nanang belum bisa memastikan apakah Raffi Ahmad sudah menerima surat panggilan itu atau belum. Saat sidang, para pihak, yakni tergugat dan penggugat dalam hal ini David Tobing sebagai penggugat dan Raffi Ahmad sebagai tergugat diharapkan hadir.David Tobing menggugat Raffi Ahmad ke Pengadilan Negeri Depok pada 15 Januari 2021. Penggugat menduga Raffi Ahmad melanggar aturan protokol kesehatan dalam Peraturan Gubernur Provinsi DKI Jakarta No. 3 tahun 2021 tentang Peraturan Pelaksanaan Peraturan Daerah Nomor 2 Tahun 2020 Tentang Penanggulangan Corona Virus Disease 2019.Termasuk juga tentang Peraturan Daerah Provinsi DKI Jakarta No. 2 tahun 2020 tentang Penanggulangan Corona Virus Disease 2019, dan Undang-Undang No. 6 tahun 2018 tentang Kekarantinaan Kesehatan.Dalam gugatannya, David Tobing ingin Raffi Ahmad tidak boleh meninggalkan rumah selama satu bulan atau 30 hari sejak penyuntikan vaksin Corona kedua diberikan kepadanya.Raffi Ahmad juga harus meminta maaf di tujuh koran, masing-masing setengah halaman, dan tujuh stasiun televisi.")
# Out:
# {'elapsed_time': 0.10598397254943848,
#  'label': 'NEUTRAL',
#  'score': 0.9892168045043945}

# %%
predict("ceboKoq perdata ?? Ahok nd sekalian kah ? Yg punya hajaat ???ng")
# Out:
# {'elapsed_time': 0.11461496353149414,
#  'label': 'NEGATIVE',
#  'score': 0.12321768701076508}

# %%
predict("saya suka gadis prancis")
# Out:
# {'elapsed_time': 0.08712315559387207,
#  'label': 'NEUTRAL',
#  'score': 0.853839635848999}

# %%
predict('saya tidak suka gadis prancis')
# Out:
# {'elapsed_time': 0.09318780899047852,
#  'label': 'NEUTRAL',
#  'score': 0.929015040397644}

# %%
predict('Saya seeokor sapi')
# Out:
# {'elapsed_time': 0.08873653411865234,
#  'label': 'NEUTRAL',
#  'score': 0.5828405618667603}

# %%
# %%time
y_pred_1d = []
y_test_1d = list(df_test.negative)
scores = model.predict(x_test, verbose=1, batch_size=300)
y_pred_1d = [decode_sentiment(score, include_neutral=False) for score in scores]
# Out:
# 9/9 [==============================] - 8s 848ms/step
# CPU times: user 13.3 s, sys: 784 ms, total: 14.1 s
# Wall time: 7.7 s

# %%
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
cnf_matrix = confusion_matrix(y_test_1d, y_pred_1d)
plt.figure(figsize=(12,12))
plot_confusion_matrix(cnf_matrix, classes=df_train.negative.unique(), title="Confusion matrix")
plt.show()

# %%
print(classification_report(y_test_1d, y_pred_1d))
# Out:
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.87      0.87      0.87      1459
#      NEUTRAL       0.84      0.84      0.84      1175
#
#     accuracy                           0.86      2634
#    macro avg       0.85      0.85      0.85      2634
# weighted avg       0.86      0.86      0.86      2634
