# %%
import requests
import pandas as pd
import json

URL = "https://www.googleapis.com/youtube/v3/commentThreads"
API_KEY = "AIzaSyDuuHAHs13ufg0OVNRAvkv1Ft7jUlNDTx4"
VIDEO_ID = "3BHBXpY7IR8&t=13s"

response = requests.get(f"{URL}?key={API_KEY}&videoId={VIDEO_ID}&part=snippet")
response_json = response.json()

print(response_json)
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': 'x6DGno482Hr9BylaCWEq0AeWy4I', 'pageInfo': {'totalResults': 18, 'resultsPerPage': 20}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'Oa-tOekINa9ks1A9p_ljGXs95a4', 'id': 'UgzeBHP8evdArwsuDa54AaABAg', 'snippet': {'videoId': '3BHBXpY7IR8', 'topLevelComment': {'kind': 'youtube#comment', 'etag': '-sQ40pvg8T8pZxdetR1P0ot8J9E', 'id': 'UgzeBHP8evdArwsuDa54AaABAg', 'snippet': {'videoId': '3BHBXpY7IR8', 'textDisplay': 'Apa kah masih ada kipas angin nya smpai sekarang, awet kah', 'textOriginal': 'Apa kah masih ada kipas angin nya smpai sekarang, awet kah', 'authorDisplayName': 'Adi Doet wongcilik', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQ8Ymq_7UgoEbyX0ssWU05aVhHY-oKi2NY7NdYikg=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCwnSkXEWvYulMNBaL0dcn4g', 'authorChannelId': {'value': 'UCwnSkXEWvYulMNBaL0dcn4g'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2021-10-27T03:35:30Z', 'updatedAt': '2021-10-27T03:35:55Z'}}, 'canReply': True, 'totalReplyCount': 3, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'YgfrE6lnSv30d21CD76OcT243rk', 'id': 'UgwBUNg5payAqdlCjo94AaABAg', 'snippet': {'videoId': '3BHBXpY7IR8', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'e9Cn31edm6BxBMYCXfwG_8WV9_w', 'id': 'UgwBUNg5payAqdlCjo94AaABAg', 'snippet': {'videoId': '3BHBXpY7IR8', 'textDisplay': 'Makasih bang sangat membantu 👍', 'textOriginal': 'Makasih bang sangat membantu 👍', 'authorDisplayName': 'budi santoso', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTV0rEMadr0YUs8INwOk-JGzVERxAH1STve6uK4DA=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCigEFrZui3stpTgByBTZBEw', 'authorChannelId': {'value': 'UCigEFrZui3stpTgByBTZBEw'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2021-10-16T12:02:03Z', 'updatedAt': '2021-10-16T12:02:03Z'}}, 'canReply': True, 'totalReplyCount': 1, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'eg25v11EPbKZxY-33KpwPexY7zg', 'id': 'Ugx9TAnWkpWqc8W1qw14AaABAg', 'snippet': {'videoId': '3BHBXpY7IR8', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'a4xN-2hOdyJ52Qat4S0Jd5cD1wA', 'id': 'Ugx9TAnWkpWqc8W1qw14AaABAg', 'snippet': {'videoId': '3BHBXpY7IR8', 'textDisplay': 'Kalo yang posisi lantai kepala ny bisa di ke atas/bawahin ga om', 'textOriginal': 'Kalo yang posisi lantai kepala ny bisa di ke atas/bawahin ga om', 'authorDisplayName': 'maydatul jannah', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRbHKyNfNtVdRQoUFbQ4QCMzX_RfVt1NsI4IBVr1_RJrmlLqebdMw_iKm1Z3pJx=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCYZp9dPuLaWxs9Do9hJHOlA', 'authorChannelId': {'value': 'UCYZp9dPuLaWxs9Do9hJHOlA'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2021-09-23T22:46:06Z', 'updatedAt': '2021-09-23T22:46:06Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'XxtolgDARckXEzO1npr0VHhoC3k', 'id': 'UgzgImiEUWLr0Z1juuV4AaABAg', 'snippet': {'videoId': '3BHBXpY7IR8', 'topLevelComment': {'kind': 'youtube#comment', 'etag': '4mi7kNijD-T9vyAPaFk0vQ1RkDI', 'id': 'UgzgImiEUWLr0Z1juuV4AaABAg', 'snippet': {'videoId': '3BHBXpY7IR8', 'textDisplay': 'Makasih mas, membantu bgt', 'textOriginal': 'Makasih mas, membantu bgt', 'authorDisplayName': 'Oko Jiwa Jiny', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLTQjhO2-KRgqK4xNMoJLKn4s-OIm53mMI_NIag12A=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCfTthMT_1jlwlgFujo7EWvQ', 'authorChannelId': {'value': 'UCfTthMT_1jlwlgFujo7EWvQ'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2021-09-20T07:52:51Z', 'updatedAt': '2021-09-20T07:52:51Z'}}, 'canReply': True, 'totalReplyCount': 1, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'ro_pnhf-9LTnyiSqGl8071yGBCs', 'id': 'UgyBD_VBiPQKC0C2e ...

# %%
comments = []
while True:
    for item in response_json["items"]:
        author = item["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"]
        content = item["snippet"]["topLevelComment"]["snippet"]["textOriginal"]
        published_at = item["snippet"]["topLevelComment"]["snippet"]["publishedAt"]
        likes = item["snippet"]["topLevelComment"]["snippet"]["likeCount"]
        reply = item["snippet"]["totalReplyCount"]
        comments.append({
            "author": author,
            "content": content,
            "published_at": published_at,
            "likes"  : likes,
            "replies" : reply
        })
        print(f"collecting from: {author}")
    
    if "nextPageToken" in response_json:
        page_token = response_json["nextPageToken"]
        response = requests.get(f"{URL}?key={API_KEY}&videoId={VIDEO_ID}&part=snippet&pageToken={page_token}")
        response_json = response.json()
    else:
        break
df = pd.DataFrame (comments, columns = ['author','content','published_at', 'likes', 'replies'])
# df.to_excel('filename.xlsx')
print(df)
# Out:
# collecting from: Adi Doet wongcilik
# collecting from: budi santoso
# collecting from: maydatul jannah
# collecting from: Oko Jiwa Jiny
# collecting from: helga maureen
# collecting from: khaurasazia arissa
# collecting from: Alisa Ramadhani
# collecting from: Novi Yantika
# collecting from: Kimkim Skizo
# collecting from: M .yansah
# collecting from: Mulyadi Sunarya
# collecting from: A. Rana Ramadhani
# collecting from: KIM HYUNWOO SHINBI'S HOUSE
# collecting from: ALS tujuhbelas
# collecting from: R_9 W.W.X
# collecting from: Windi Kids
# collecting from: Tengku Novia Widia Sari
# collecting from: Darwin Studio
#                         author  ... replies
# 0           Adi Doet wongcilik  ...       3
# 1                 budi santoso  ...       1
# 2              maydatul jannah  ...       0
# 3                Oko Jiwa Jiny  ...       1
# 4                helga maureen  ...       1
# 5           khaurasazia arissa  ...       1
# 6              Alisa Ramadhani  ...       1
# 7                 Novi Yantika  ...       1
# 8                 Kimkim Skizo  ...       1
# 9                    M .yansah  ...       1
# 10             Mulyadi Sunarya  ...       2
# 11           A. Rana Ramadhani  ...       1
# 12  KIM HYUNWOO SHINBI'S HOUSE  ...       0
# 13              ALS tujuhbelas  ...       1
# 14                   R_9 W.W.X  ...       1
# 15                  Windi Kids  ...       1
# 16     Tengku Novia Widia Sari  ...       1
# 17               Darwin Studio  ...       1
#
# [18 rows x 5 columns]

# %%
df
# Out:
#                         author  ... replies
# 0           Adi Doet wongcilik  ...       3
# 1                 budi santoso  ...       1
# 2              maydatul jannah  ...       0
# 3                Oko Jiwa Jiny  ...       1
# 4                helga maureen  ...       1
# 5           khaurasazia arissa  ...       1
# 6              Alisa Ramadhani  ...       1
# 7                 Novi Yantika  ...       1
# 8                 Kimkim Skizo  ...       1
# 9                    M .yansah  ...       1
# 10             Mulyadi Sunarya  ...       2
# 11           A. Rana Ramadhani  ...       1
# 12  KIM HYUNWOO SHINBI'S HOUSE  ...       0
# 13              ALS tujuhbelas  ...       1
# 14                   R_9 W.W.X  ...       1
# 15                  Windi Kids  ...       1
# 16     Tengku Novia Widia Sari  ...       1
# 17               Darwin Studio  ...       1
#
# [18 rows x 5 columns]
